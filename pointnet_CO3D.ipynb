# %%
import os
import numpy as np
import trimesh
import tensorflow as tf

import matplotlib 
import matplotlib.pyplot as plt

# %%
def load_point_cloud(file_path, num_points=1024):
    mesh = trimesh.load(file_path)

    # Si es una escena, combinar geometrías
    if isinstance(mesh, trimesh.Scene):
        mesh = trimesh.util.concatenate([geometry for geometry in mesh.geometry.values()])

    # Si es una nube de puntos
    if isinstance(mesh, trimesh.PointCloud):
        points = mesh.vertices  # Acceder directamente a los puntos
        if len(points) > num_points:
            indices = np.random.choice(len(points), num_points, replace=False)
            points = points[indices]
        elif len(points) < num_points:
            # Si hay menos puntos, repetir hasta completar
            points = np.tile(points, (num_points // len(points) + 1, 1))[:num_points]
        return points.astype(np.float32)

    # Si es una malla
    elif isinstance(mesh, trimesh.Trimesh):
        points = mesh.sample(num_points)
        return points.astype(np.float32)

    else:
        raise ValueError(f"El archivo {file_path} no es una malla ni una nube de puntos.")


def load_dataset(base_path, num_points=1024):
    data = []
    labels = []
    i=0
    # Botellas (clase 0)
    for dataset in ['bottle']:
        folder_path = os.path.join(base_path, dataset)
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            file_path = os.path.join(subfolder_path, 'pointcloud.ply')
            if os.path.exists(file_path):
                try:
                    data.append(load_point_cloud(file_path, num_points))
                    labels.append(0)  # Clase 0: Botella
                    print(f"Added {dataset } num {i} ")
                    i+=1
                except Exception as e:
                    print(f"Error al cargar {file_path}: {e}")
    print(f"Categoria Bottle cargada")
    # Patinetas (clase 1)
    i=0
    for dataset in ['car']:
        folder_path = os.path.join(base_path, dataset)
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            file_path = os.path.join(subfolder_path, 'pointcloud.ply')
            if os.path.exists(file_path):
                try:
                    data.append(load_point_cloud(file_path, num_points))
                    labels.append(1)  # Clase 1: car
                    print(f"Added {dataset } num {i} ")
                    i+=1
                except Exception as e:
                    print(f"Error al cargar {file_path}: {e}")
    print(f"Categoria car cargada")
    # Patinetas (clase 1)
    i=0
    for dataset in ['laptop']:
        folder_path = os.path.join(base_path, dataset)
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            file_path = os.path.join(subfolder_path, 'pointcloud.ply')
            if os.path.exists(file_path):
                try:
                    data.append(load_point_cloud(file_path, num_points))
                    labels.append(2)  # Clase 2: laptop
                    print(f"Added {dataset } num {i} ")
                    i+=1
                except Exception as e:
                    print(f"Error al cargar {file_path}: {e}")
    print(f"Categoria laptop cargada")
    # Patinetas (clase 1)
    i=0
    for dataset in ['skateboard']:
        folder_path = os.path.join(base_path, dataset)
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            file_path = os.path.join(subfolder_path, 'pointcloud.ply')
            if os.path.exists(file_path):
                try:
                    data.append(load_point_cloud(file_path, num_points))
                    labels.append(3)  # Clase 3: skateboard
                    print(f"Added {dataset } num {i} ")
                    i+=1
                except Exception as e:
                    print(f"Error al cargar {file_path}: {e}")
    print(f"Categoria skateboard cargada")
    
    

    return np.array(data), np.array(labels)


# Configuración
DATA_PATH = "B:/MasterIE/datasets/CO3D"  # Cambia a tu ruta
x_data, y_data = load_dataset(DATA_PATH, num_points=1024)
print("Shape de los datos:", x_data.shape)
print("Shape de las etiquetas:", y_data.shape)
# Out:
# Added bottle num 0
# Added bottle num 1
# Added bottle num 2
# Added bottle num 3
# Added bottle num 4
# Added bottle num 5
# Added bottle num 6
# Added bottle num 7
# Added bottle num 8
# Added bottle num 9
# Added bottle num 10
# Added bottle num 11
# Added bottle num 12
# Added bottle num 13
# Added bottle num 14
# Added bottle num 15
# Added bottle num 16
# Added bottle num 17
# Added bottle num 18
# Added bottle num 19
# Added bottle num 20
# Added bottle num 21
# Added bottle num 22
# Added bottle num 23
# Added bottle num 24
# Added bottle num 25
# Added bottle num 26
# Added bottle num 27
# Added bottle num 28
# Added bottle num 29
# Added bottle num 30
# Added bottle num 31
# Added bottle num 32
# Added bottle num 33
# Added bottle num 34
# Added bottle num 35
# Added bottle num 36
# Added bottle num 37
# Added bottle num 38
# Added bottle num 39
# Added bottle num 40
# Added bottle num 41
# Added bottle num 42
# Added bottle num 43
# Added bottle num 44
# Added bottle num 45
# Added bottle num 46
# Added bottle num 47
# Added bottle num 48
# Added bottle num 49
# Added bottle num 50
# Added bottle num 51
# Added bottle num 52
# Added bottle num 53
# Added bottle num 54
# Added bottle num 55
# Added bottle num 56
# Added bottle num 57
# Added bottle num 58
# Added bottle num 59
# Added bottle num 60
# Added bottle num 61
# Added bottle num 62
# Added bottle num 63
# Added bottle num 64
# Added bottle num 65
# Added bottle num 66
# Added bottle num 67
# Added bottle num 68
# Added bottle num 69
# Added bottle num 70
# Added bottle num 71
# Added bottle num 72
# Added bottle num 73
# Added bottle num 74
# Added bottle num 75
# Added bottle num 76
# Added bottle num 77
# Added bottle num 78
# Added bottle num 79
# Added bottle num 80
# Added bottle num 81
# Added bottle num 82
# Added bottle num 83
# Added bottle num 84
# Added bottle num 85
# Added bottle num 86
# Added bottle num 87
# Added bottle num 88
# Added bottle num 89
# Added bottle num 90
# Added bottle num 91
# Added bottle num 92
# Added bottle num 93
# Added bottle num 94
# Added bottle num 95
# Added bottle num 96
# Added bottle num 97
# Added bottle num 98
# Added bottle num 99
# Added bottle num 100
# Added bottle num 101
# Added bottle num 102
# Added bottle num 103
# Added bottle num 104
# Added bottle num 105
# Added bottle num 106
# Added bottle num 107
# Added bottle num 108
# Added bottle num 109
# Added bottle num 110
# Added bottle num 111
# Added bottle num 112
# Added bottle num 113
# Added bottle num 114
# Added bottle num 115
# Added bottle num 116
# Added bottle num 117
# Added bottle num 118
# Added bottle num 119
# Added bottle num 120
# Added bottle num 121
# Added bottle num 122
# Added bottle num 123
# Added bottle num 124
# Added bottle num 125
# Added bottle num 126
# Added bottle num 127
# Added bottle num 128
# Added bottle num 129
# Added bottle num 130
# Added bottle num 131
# Added bottle num 132
# Added bottle num 133
# Added bottle num 134
# Added bottle num 135
# Added bottle num 136
# Added bottle num 137
# Added bottle num 138
# Added bottle num 139
# Added bottle num 140
# Added bottle num 141
# Added bottle num 142
# Added bottle num 143
# Added bottle num 144
# Added bottle num 145
# Added bottle num 146
# Added bottle num 147
# Added bottle num 148
# Added bottle num 149
# Added bottle num 150
# Added bottle num 151
# Added bottle num 152
# Added bottle num 153
# Added bottle num 154
# Added bottle num 155
# Added bottle num 156
# Added bottle num 157
# Added bottle num 158
# Added bottle num 159
# Added bottle num 160
# Added bottle num 161
# Added bottle num 162
# Added bottle num 163
# Added bottle num 164
# Added bottle num 165
# Added bottle num 166
# Added bottle num 167
# Added bottle num 168
# Added bottle num 169
# Added bottle num 170
# Added bottle num 171
# Added bottle num 172
# Added bottle num 173
# Added bottle num 174
# Added bottle num 175
# Added bottle num 176
# Added bottle num 177
# Added bottle num 178
# Added bottle num 179
# Added bottle num 180
# Added bottle num 181
# Added bottle num 182
# Added bottle num 183
# Added bottle num 184
# Added bottle num 185
# Added bottle num 186
# Added bottle num 187
# Added bottle num 188
# Added bottle num 189
# Added bottle num 190
# Added bottle num 191
# Added bottle num 192
# Added bottle num 193
# Added bottle num 194
# Added bottle num 195
# Added bottle num 196
# Added bottle num 197
# Added bottle num 198
# Added bottle num 199
# Added bottle num 200
# Added bottle num 201
# Added bottle num 202
# Added bottle num 203
# Added bottle num 204
# Added bottle num 205
# Added bottle num 206
# Added bottle num 207
# Added bottle num 208
# Added bottle num 209
# Added bottle num 210
# Added bottle num 211
# Added bottle num 212
# Added bottle num 213
# Added bottle num 214
# Added bottle num 215
# Added bottle num 216
# Added bottle num 217
# Added bottle num 218
# Added bottle num 219
# Added bottle num 220
# Added bottle num 221
# Added bottle num 222
# Added bottle num 223
# Added bottle num 224
# Added bottle num 225
# Added bottle num 226
# Added bottle num 227
# Added bottle num 228
# Added bottle num 229
# Added bottle num 230
# Added bottle num 231
# Added bottle num 232
# Added bottle num 233
# Added bottle num 234
# Added bottle num 235
# Added bottle num 236
# Added bottle num 237
# Added bottle num 238
# Added bottle num 239
# Added bottle num 240
# Added bottle num 241
# Added bottle num 242
# Added bottle num 243
# Added bottle num 244
# Added bottle num 245
# Added bottle num 246
# Added bottle num 247
# Added bottle num 248
# Added bottle num 249
# Added bottle num 250
# Added bottle num 251
# Added bottle num 252
# Added bottle num 253
# Added bottle num 254
# Added bottle num 255
# Added bottle num 256
# Added bottle num 257
# Added bottle num 258
# Added bottle num 259
# Added bottle num 260
# Added bottle num 261
# Added bottle num 262
# Added bottle num 263
# Added bottle num 264
# Added bottle num 265
# Added bottle num 266
# Added bottle num 267
# Added bottle num 268
# Added bottle num 269
# Added bottle num 270
# Added bottle num 271
# Added bottle num 272
# Added bottle num 273
# Added bottle num 274
# Added bottle num 275
# Added bottle num 276
# Added bottle num 277
# Added bottle num 278
# Added bottle num 279
# Added bottle num 280
# Added bottle num 281
# Added bottle num 282
# Added bottle num 283
# Added bottle num 284
# Added bottle num 285
# Added bottle num 286
# Added bottle num 287
# Added bottle num 288
# Added bottle num 289
# Added bottle num 290
# Added bottle num 291
# Added bottle num 292
# Added bottle num 293
# Added bottle num 294
# Added bottle num 295
# Added bottle num 296
# Added bottle num 297
# Categoria Bottle cargada
# Added car num 0
# Added car num 1
# Added car num 2
# Added car num 3
# Added car num 4
# Added car num 5
# Added car num 6
# Added car num 7
# Added car num 8
# Added car num 9
# Added car num 10
# Added car num 11
# Added car num 12
# Added car num 13
# Added car num 14
# Added car num 15
# Added car num 16
# Added car num 17
# Added car num 18
# Added car num 19
# Added car num 20
# Added car num 21
# Added car num 22
# Added car num 23
# Added car num 24
# Added car num 25
# Added car num 26
# Added car num 27
# Added car num 28
# Added car num 29
# Added car num 30
# Added car num 31
# Added car num 32
# Added car num 33
# Added car num 34
# Added car num 35
# Added car num 36
# Added car num 37
# Added car num 38
# Added car num 39
# Added car num 40
# Added car num 41
# Added car num 42
# Added car num 43
# Added car num 44
# Added car num 45
# Added car num 46
# Added car num 47
# Added car num 48
# Added car num 49
# Added car num 50
# Added car num 51
# Added car num 52
# Added car num 53
# Added car num 54
# Added car num 55
# Added car num 56
# Added car num 57
# Added car num 58
# Added car num 59
# Added car num 60
# Added car num 61
# Added car num 62
# Added car num 63
# Added car num 64
# Added car num 65
# Added car num 66
# Added car num 67
# Added car num 68
# Added car num 69
# Added car num 70
# Added car num 71
# Added car num 72
# Added car num 73
# Added car num 74
# Added car num 75
# Added car num 76
# Added car num 77
# Added car num 78
# Added car num 79
# Added car num 80
# Added car num 81
# Added car num 82
# Added car num 83
# Added car num 84
# Added car num 85
# Added car num 86
# Added car num 87
# Added car num 88
# Added car num 89
# Added car num 90
# Added car num 91
# Added car num 92
# Added car num 93
# Added car num 94
# Added car num 95
# Added car num 96
# Added car num 97
# Added car num 98
# Added car num 99
# Added car num 100
# Added car num 101
# Added car num 102
# Added car num 103
# Added car num 104
# Added car num 105
# Added car num 106
# Added car num 107
# Added car num 108
# Added car num 109
# Added car num 110
# Added car num 111
# Added car num 112
# Added car num 113
# Added car num 114
# Added car num 115
# Added car num 116
# Added car num 117
# Added car num 118
# Added car num 119
# Added car num 120
# Added car num 121
# Added car num 122
# Added car num 123
# Added car num 124
# Added car num 125
# Added car num 126
# Added car num 127
# Added car num 128
# Added car num 129
# Added car num 130
# Added car num 131
# Added car num 132
# Added car num 133
# Added car num 134
# Added car num 135
# Added car num 136
# Added car num 137
# Added car num 138
# Added car num 139
# Added car num 140
# Added car num 141
# Added car num 142
# Added car num 143
# Categoria car cargada
# Added laptop num 0
# Added laptop num 1
# Added laptop num 2
# Added laptop num 3
# Added laptop num 4
# Added laptop num 5
# Added laptop num 6
# Added laptop num 7
# Added laptop num 8
# Added laptop num 9
# Added laptop num 10
# Added laptop num 11
# Added laptop num 12
# Added laptop num 13
# Added laptop num 14
# Added laptop num 15
# Added laptop num 16
# Added laptop num 17
# Added laptop num 18
# Added laptop num 19
# Added laptop num 20
# Added laptop num 21
# Added laptop num 22
# Added laptop num 23
# Added laptop num 24
# Added laptop num 25
# Added laptop num 26
# Added laptop num 27
# Added laptop num 28
# Added laptop num 29
# Added laptop num 30
# Added laptop num 31
# Added laptop num 32
# Added laptop num 33
# Added laptop num 34
# Added laptop num 35
# Added laptop num 36
# Added laptop num 37
# Added laptop num 38
# Added laptop num 39
# Added laptop num 40
# Added laptop num 41
# Added laptop num 42
# Added laptop num 43
# Added laptop num 44
# Added laptop num 45
# Added laptop num 46
# Added laptop num 47
# Added laptop num 48
# Added laptop num 49
# Added laptop num 50
# Added laptop num 51
# Added laptop num 52
# Added laptop num 53
# Added laptop num 54
# Added laptop num 55
# Added laptop num 56
# Added laptop num 57
# Added laptop num 58
# Added laptop num 59
# Added laptop num 60
# Added laptop num 61
# Added laptop num 62
# Added laptop num 63
# Added laptop num 64
# Added laptop num 65
# Added laptop num 66
# Added laptop num 67
# Added laptop num 68
# Added laptop num 69
# Added laptop num 70
# Added laptop num 71
# Added laptop num 72
# Added laptop num 73
# Added laptop num 74
# Added laptop num 75
# Added laptop num 76
# Added laptop num 77
# Added laptop num 78
# Added laptop num 79
# Added laptop num 80
# Added laptop num 81
# Added laptop num 82
# Added laptop num 83
# Added laptop num 84
# Added laptop num 85
# Added laptop num 86
# Added laptop num 87
# Added laptop num 88
# Added laptop num 89
# Added laptop num 90
# Added laptop num 91
# Added laptop num 92
# Added laptop num 93
# Added laptop num 94
# Added laptop num 95
# Added laptop num 96
# Added laptop num 97
# Added laptop num 98
# Added laptop num 99
# Added laptop num 100
# Added laptop num 101
# Added laptop num 102
# Added laptop num 103
# Added laptop num 104
# Added laptop num 105
# Added laptop num 106
# Added laptop num 107
# Added laptop num 108
# Added laptop num 109
# Added laptop num 110
# Added laptop num 111
# Added laptop num 112
# Added laptop num 113
# Added laptop num 114
# Added laptop num 115
# Added laptop num 116
# Added laptop num 117
# Added laptop num 118
# Added laptop num 119
# Added laptop num 120
# Added laptop num 121
# Added laptop num 122
# Added laptop num 123
# Added laptop num 124
# Added laptop num 125
# Added laptop num 126
# Added laptop num 127
# Added laptop num 128
# Added laptop num 129
# Added laptop num 130
# Added laptop num 131
# Added laptop num 132
# Added laptop num 133
# Added laptop num 134
# Added laptop num 135
# Added laptop num 136
# Added laptop num 137
# Added laptop num 138
# Added laptop num 139
# Added laptop num 140
# Added laptop num 141
# Added laptop num 142
# Added laptop num 143
# Added laptop num 144
# Added laptop num 145
# Added laptop num 146
# Added laptop num 147
# Added laptop num 148
# Added laptop num 149
# Added laptop num 150
# Added laptop num 151
# Added laptop num 152
# Added laptop num 153
# Added laptop num 154
# Added laptop num 155
# Added laptop num 156
# Added laptop num 157
# Added laptop num 158
# Added laptop num 159
# Added laptop num 160
# Added laptop num 161
# Added laptop num 162
# Added laptop num 163
# Added laptop num 164
# Added laptop num 165
# Added laptop num 166
# Added laptop num 167
# Added laptop num 168
# Added laptop num 169
# Added laptop num 170
# Added laptop num 171
# Added laptop num 172
# Added laptop num 173
# Added laptop num 174
# Added laptop num 175
# Added laptop num 176
# Added laptop num 177
# Added laptop num 178
# Added laptop num 179
# Added laptop num 180
# Added laptop num 181
# Added laptop num 182
# Added laptop num 183
# Added laptop num 184
# Added laptop num 185
# Added laptop num 186
# Added laptop num 187
# Added laptop num 188
# Added laptop num 189
# Added laptop num 190
# Added laptop num 191
# Added laptop num 192
# Added laptop num 193
# Added laptop num 194
# Added laptop num 195
# Added laptop num 196
# Added laptop num 197
# Added laptop num 198
# Added laptop num 199
# Added laptop num 200
# Added laptop num 201
# Added laptop num 202
# Added laptop num 203
# Added laptop num 204
# Added laptop num 205
# Added laptop num 206
# Added laptop num 207
# Added laptop num 208
# Added laptop num 209
# Added laptop num 210
# Added laptop num 211
# Added laptop num 212
# Added laptop num 213
# Added laptop num 214
# Added laptop num 215
# Added laptop num 216
# Added laptop num 217
# Added laptop num 218
# Added laptop num 219
# Added laptop num 220
# Added laptop num 221
# Added laptop num 222
# Added laptop num 223
# Added laptop num 224
# Added laptop num 225
# Added laptop num 226
# Added laptop num 227
# Added laptop num 228
# Added laptop num 229
# Added laptop num 230
# Added laptop num 231
# Added laptop num 232
# Added laptop num 233
# Added laptop num 234
# Added laptop num 235
# Added laptop num 236
# Added laptop num 237
# Added laptop num 238
# Added laptop num 239
# Added laptop num 240
# Added laptop num 241
# Added laptop num 242
# Added laptop num 243
# Added laptop num 244
# Added laptop num 245
# Added laptop num 246
# Added laptop num 247
# Added laptop num 248
# Added laptop num 249
# Added laptop num 250
# Added laptop num 251
# Added laptop num 252
# Added laptop num 253
# Added laptop num 254
# Added laptop num 255
# Added laptop num 256
# Added laptop num 257
# Added laptop num 258
# Added laptop num 259
# Added laptop num 260
# Added laptop num 261
# Added laptop num 262
# Added laptop num 263
# Added laptop num 264
# Added laptop num 265
# Added laptop num 266
# Added laptop num 267
# Added laptop num 268
# Added laptop num 269
# Added laptop num 270
# Added laptop num 271
# Added laptop num 272
# Added laptop num 273
# Added laptop num 274
# Added laptop num 275
# Added laptop num 276
# Added laptop num 277
# Added laptop num 278
# Added laptop num 279
# Added laptop num 280
# Added laptop num 281
# Added laptop num 282
# Added laptop num 283
# Added laptop num 284
# Added laptop num 285
# Added laptop num 286
# Added laptop num 287
# Added laptop num 288
# Added laptop num 289
# Added laptop num 290
# Added laptop num 291
# Added laptop num 292
# Added laptop num 293
# Added laptop num 294
# Added laptop num 295
# Added laptop num 296
# Categoria laptop cargada
# Added skateboard num 0
# Added skateboard num 1
# Added skateboard num 2
# Added skateboard num 3
# Added skateboard num 4
# Added skateboard num 5
# Added skateboard num 6
# Added skateboard num 7
# Added skateboard num 8
# Added skateboard num 9
# Added skateboard num 10
# Added skateboard num 11
# Added skateboard num 12
# Added skateboard num 13
# Added skateboard num 14
# Added skateboard num 15
# Added skateboard num 16
# Added skateboard num 17
# Added skateboard num 18
# Added skateboard num 19
# Added skateboard num 20
# Added skateboard num 21
# Added skateboard num 22
# Added skateboard num 23
# Added skateboard num 24
# Added skateboard num 25
# Added skateboard num 26
# Added skateboard num 27
# Added skateboard num 28
# Added skateboard num 29
# Added skateboard num 30
# Added skateboard num 31
# Added skateboard num 32
# Added skateboard num 33
# Added skateboard num 34
# Added skateboard num 35
# Added skateboard num 36
# Added skateboard num 37
# Added skateboard num 38
# Added skateboard num 39
# Added skateboard num 40
# Added skateboard num 41
# Added skateboard num 42
# Added skateboard num 43
# Added skateboard num 44
# Added skateboard num 45
# Added skateboard num 46
# Added skateboard num 47
# Added skateboard num 48
# Added skateboard num 49
# Added skateboard num 50
# Added skateboard num 51
# Added skateboard num 52
# Added skateboard num 53
# Added skateboard num 54
# Added skateboard num 55
# Added skateboard num 56
# Added skateboard num 57
# Added skateboard num 58
# Added skateboard num 59
# Added skateboard num 60
# Added skateboard num 61
# Added skateboard num 62
# Added skateboard num 63
# Added skateboard num 64
# Added skateboard num 65
# Added skateboard num 66
# Added skateboard num 67
# Added skateboard num 68
# Added skateboard num 69
# Added skateboard num 70
# Added skateboard num 71
# Added skateboard num 72
# Added skateboard num 73
# Added skateboard num 74
# Added skateboard num 75
# Added skateboard num 76
# Added skateboard num 77
# Added skateboard num 78
# Added skateboard num 79
# Added skateboard num 80
# Added skateboard num 81
# Categoria skateboard cargada
# Shape de los datos: (821, 1024, 3)
# Shape de las etiquetas: (821,)

# %%
unique, counts = np.unique(y_data, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Distribucion de clases antes del equilibrio:",class_distribution)
plt.bar(class_distribution.keys(), class_distribution.values(), tick_label=['Bottle', 'Car', 'Laptop', 'Skateboard'])
plt.title("Distribucion de las clases antes del equilibrio")
plt.show()
# Out:
# Distribucion de clases antes del equilibrio: {0: 298, 1: 144, 2: 297, 3: 82}

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42, stratify=y_data)

print("Shape de x_train:", x_train.shape)
print("Shape de y_train:", y_train.shape)
print("Shape de x_test:", x_test.shape)
print("Shape de y_test:", y_test.shape)
# Out:
# Shape de x_train: (656, 1024, 3)
# Shape de y_train: (656,)
# Shape de x_test: (165, 1024, 3)
# Shape de y_test: (165,)

# %%
from sklearn.utils import resample

def balance_dataset(x, y):
    classes = np.unique(y)
    x_balanced = []
    y_balanced = []

    # Encontrar el tamaño mínimo
    min_samples = min([np.sum(y == c) for c in classes])

    # Reequilibrar cada clase
    for c in classes:
        x_class = x[y == c]
        y_class = y[y == c]
        
        # Submuestrear la clase al tamaño mínimo
        x_resampled, y_resampled = resample(x_class, y_class, replace=False, n_samples=min_samples, random_state=42)
        x_balanced.append(x_resampled)
        y_balanced.append(y_resampled)
    
    return np.vstack(x_balanced), np.hstack(y_balanced)

# Aplicar submuestreo
x_train_balanced, y_train_balanced = balance_dataset(x_train, y_train)
unique, counts = np.unique(y_train_balanced, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Distribucion de clases antes del equilibrio:",class_distribution)
plt.bar(class_distribution.keys(), class_distribution.values(), tick_label=['Bottle', 'Car', 'Laptop', 'Skateboard'])
plt.title("Distribucion de las clases despues del equilibrio")
plt.show()
# Out:
# Distribucion de clases antes del equilibrio: {0: 66, 1: 66, 2: 66, 3: 66}

# %%
from tensorflow import keras
from tensorflow.keras import layers


def pointNet_buena(num_clases=4, num_points=1024):
    inputs = keras.Input(shape=(num_points,3))
    
    #expandir dimensiones para aplicar convs 2D 
    x = layers.Reshape((num_points,3,1))(inputs)
    x = layers.Conv2D(64, (1,3), activation='relu', padding='valid')(x)
    x = layers.Conv2D(64, (1,1), activation='relu', padding='valid')(x)
    x = layers.Conv2D(64, (1,1), activation='relu', padding='valid')(x)
    x = layers.Conv2D(128, (1,1), activation='relu', padding='valid')(x)
    x = layers.Conv2D(1024, (1,1), activation='relu', padding='valid')(x)
    x = layers.Dropout(0.15)(x)
    #maxpooling global
    x= layers.GlobalMaxPooling2D()(x)
    #capas conectadas completamente
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.7)(x)
    outputs = layers.Dense(num_clases, activation='softmax')(x)
    model = keras.Model(inputs, outputs,name="PointNet")
    return model

def pointnet_oficial(num_points=2048, num_classes=4):
    inputs = tf.keras.Input(shape=(num_points, 3))
    
    # Transformación de Entrada (T-Net)
    x = tf.keras.layers.Conv1D(64, 1, activation='relu')(inputs)
    x = tf.keras.layers.Conv1D(128, 1, activation='relu')(x)
    x = tf.keras.layers.Conv1D(1024, 1, activation='relu')(x)
    x = tf.keras.layers.GlobalMaxPooling1D()(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    t_net = tf.keras.layers.Dense(9, kernel_initializer='zeros', bias_initializer='zeros')(x)
    t_net = tf.keras.layers.Reshape((3, 3))(t_net)
    
    # Aplicar la transformación a los puntos
    transformed_inputs = tf.linalg.matmul(inputs, t_net)
    
    # MLP Compartido (Perceptrón Multicapa)
    x = tf.keras.layers.Conv1D(64, 1, activation='relu')(transformed_inputs)
    x = tf.keras.layers.Conv1D(64, 1, activation='relu')(x)
    
    # Transformación de Características (T-Net para características)
    x_t = tf.keras.layers.Conv1D(64, 1, activation='relu')(x)
    x_t = tf.keras.layers.Conv1D(128, 1, activation='relu')(x_t)
    x_t = tf.keras.layers.Conv1D(1024, 1, activation='relu')(x_t)
    x_t = tf.keras.layers.GlobalMaxPooling1D()(x_t)
    x_t = tf.keras.layers.Dense(512, activation='relu')(x_t)
    x_t = tf.keras.layers.Dense(256, activation='relu')(x_t)
    f_t_net = tf.keras.layers.Dense(64 * 64, kernel_initializer='zeros')(x_t)
    f_t_net = tf.keras.layers.Reshape((64, 64))(f_t_net)
    
    # Aplicar la transformación de características
    x = tf.linalg.matmul(x, f_t_net)
    
    # MLP Compartido (Continuación)
    x = tf.keras.layers.Conv1D(64, 1, activation='relu')(x)
    x = tf.keras.layers.Conv1D(128, 1, activation='relu')(x)
    x = tf.keras.layers.Conv1D(1024, 1, activation='relu')(x)
    
    # Agregación Global (Max Pooling)
    x = tf.keras.layers.GlobalMaxPooling1D()(x)
    
    # MLP Global (Clasificación)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
    # Definir el modelo
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Compilar el modelo
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# model = pointnet_model()
model = pointNet_buena()
#model = pointnet_oficial()
model.summary()
# Out:
# Model: "PointNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 1024, 3)]         0
#
#  reshape_14 (Reshape)        (None, 1024, 3, 1)        0
#
#  conv2d_30 (Conv2D)          (None, 1024, 1, 64)       256
#
#  conv2d_31 (Conv2D)          (None, 1024, 1, 64)       4160
#
#  conv2d_32 (Conv2D)          (None, 1024, 1, 64)       4160
#
#  conv2d_33 (Conv2D)          (None, 1024, 1, 128)      8320
#
#  conv2d_34 (Conv2D)          (None, 1024, 1, 1024)     132096
#
#  dropout_22 (Dropout)        (None, 1024, 1, 1024)     0
#
#  global_max_pooling2d_6 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  dense_54 (Dense)            (None, 512)               524800
#
#  batch_normalization_12 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_55 (Dense)            (None, 256)               131328
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_24 (Dropout)        (None, 256)               0
#
#  dense_56 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 809,220
# Trainable params: 807,684
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
# SAVING THE TRAINED MODEL
checkpoint_path = "C:/Users/Luis/Desktop/pointnet/model_trained"
checkpoint_dir= os.path.dirname(checkpoint_path)

#callback
batch_size=32
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_freq=2*batch_size,
                                                 verbose=1)

# %%
model.compile(optimizer='adam', loss="sparse_categorical_crossentropy",metrics=['accuracy'])
history = model.fit(x_train_balanced,
          y_train_balanced,
          epochs=55,
          batch_size=32,
          validation_data=(x_test, y_test),  # Usamos el set de prueba como validación
          callbacks=[cp_callback])
# Out:
# Epoch 1/55
# 21/21 [==============================] - 4s 125ms/step - loss: 1.3218 - accuracy: 0.6479 - val_loss: 1.2407 - val_accuracy: 0.6727
# Epoch 2/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.9149 - accuracy: 0.7256 - val_loss: 1.1428 - val_accuracy: 0.6788
# Epoch 3/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.6571 - accuracy: 0.7881 - val_loss: 1.0924 - val_accuracy: 0.6909
# Epoch 4/55
#
# Epoch 4: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 99ms/step - loss: 0.7275 - accuracy: 0.7881 - val_loss: 1.0683 - val_accuracy: 0.6121
# Epoch 5/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.5099 - accuracy: 0.8262 - val_loss: 0.9827 - val_accuracy: 0.7091
# Epoch 6/55
# 21/21 [==============================] - 2s 101ms/step - loss: 0.5360 - accuracy: 0.8399 - val_loss: 0.9304 - val_accuracy: 0.6970
# Epoch 7/55
#  1/21 [>.............................] - ETA: 1s - loss: 0.1696 - accuracy: 0.9375
# Epoch 7: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 104ms/step - loss: 0.4283 - accuracy: 0.8659 - val_loss: 0.8513 - val_accuracy: 0.7091
# Epoch 8/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.3848 - accuracy: 0.8735 - val_loss: 0.8061 - val_accuracy: 0.7091
# Epoch 9/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.4090 - accuracy: 0.8750 - val_loss: 0.8729 - val_accuracy: 0.6182
# Epoch 10/55
#  2/21 [=>............................] - ETA: 1s - loss: 0.1223 - accuracy: 0.9844
# Epoch 10: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 107ms/step - loss: 0.3130 - accuracy: 0.8948 - val_loss: 0.7643 - val_accuracy: 0.7818
# Epoch 11/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.2914 - accuracy: 0.9024 - val_loss: 0.6254 - val_accuracy: 0.8485
# Epoch 12/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.2709 - accuracy: 0.9040 - val_loss: 0.6074 - val_accuracy: 0.7758
# Epoch 13/55
#  3/21 [===>..........................] - ETA: 1s - loss: 0.1842 - accuracy: 0.9479
# Epoch 13: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2558 - accuracy: 0.9085 - val_loss: 0.5725 - val_accuracy: 0.8182
# Epoch 14/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.2795 - accuracy: 0.9024 - val_loss: 0.4316 - val_accuracy: 0.8545
# Epoch 15/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.2791 - accuracy: 0.9055 - val_loss: 0.4791 - val_accuracy: 0.8242
# Epoch 16/55
#  4/21 [====>.........................] - ETA: 1s - loss: 0.3178 - accuracy: 0.8828
# Epoch 16: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2769 - accuracy: 0.9055 - val_loss: 0.6617 - val_accuracy: 0.7636
# Epoch 17/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1967 - accuracy: 0.9314 - val_loss: 0.3032 - val_accuracy: 0.9152
# Epoch 18/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1742 - accuracy: 0.9375 - val_loss: 0.4051 - val_accuracy: 0.8364
# Epoch 19/55
#  5/21 [======>.......................] - ETA: 1s - loss: 0.2171 - accuracy: 0.9250
# Epoch 19: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2070 - accuracy: 0.9268 - val_loss: 0.4357 - val_accuracy: 0.8364
# Epoch 20/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1993 - accuracy: 0.9436 - val_loss: 0.5468 - val_accuracy: 0.8000
# Epoch 21/55
# 21/21 [==============================] - 3s 125ms/step - loss: 0.1520 - accuracy: 0.9421 - val_loss: 0.4743 - val_accuracy: 0.8364
# Epoch 22/55
#  6/21 [=======>......................] - ETA: 1s - loss: 0.1757 - accuracy: 0.9323
# Epoch 22: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1967 - accuracy: 0.9375 - val_loss: 0.2113 - val_accuracy: 0.9091
# Epoch 23/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1856 - accuracy: 0.9421 - val_loss: 0.3093 - val_accuracy: 0.8788
# Epoch 24/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1867 - accuracy: 0.9421 - val_loss: 0.3844 - val_accuracy: 0.8848
# Epoch 25/55
#  7/21 [=========>....................] - ETA: 1s - loss: 0.1682 - accuracy: 0.9241
# Epoch 25: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1497 - accuracy: 0.9390 - val_loss: 0.3503 - val_accuracy: 0.8727
# Epoch 26/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1615 - accuracy: 0.9436 - val_loss: 0.2400 - val_accuracy: 0.9212
# Epoch 27/55
# 21/21 [==============================] - 2s 101ms/step - loss: 0.1358 - accuracy: 0.9497 - val_loss: 0.1903 - val_accuracy: 0.9515
# Epoch 28/55
#  8/21 [==========>...................] - ETA: 1s - loss: 0.1998 - accuracy: 0.9375
# Epoch 28: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1385 - accuracy: 0.9558 - val_loss: 0.7439 - val_accuracy: 0.8424
# Epoch 29/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1062 - accuracy: 0.9634 - val_loss: 0.4828 - val_accuracy: 0.8970
# Epoch 30/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.0944 - accuracy: 0.9619 - val_loss: 0.3829 - val_accuracy: 0.8667
# Epoch 31/55
#  9/21 [===========>..................] - ETA: 1s - loss: 0.1016 - accuracy: 0.9688
# Epoch 31: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 110ms/step - loss: 0.0992 - accuracy: 0.9649 - val_loss: 0.3388 - val_accuracy: 0.8788
# Epoch 32/55
# 21/21 [==============================] - 2s 101ms/step - loss: 0.1207 - accuracy: 0.9558 - val_loss: 0.4325 - val_accuracy: 0.8727
# Epoch 33/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1124 - accuracy: 0.9558 - val_loss: 0.8611 - val_accuracy: 0.8121
# Epoch 34/55
# 10/21 [=============>................] - ETA: 1s - loss: 0.1225 - accuracy: 0.9563
# Epoch 34: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 107ms/step - loss: 0.1522 - accuracy: 0.9512 - val_loss: 0.7499 - val_accuracy: 0.8364
# Epoch 35/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1562 - accuracy: 0.9527 - val_loss: 0.5561 - val_accuracy: 0.8364
# Epoch 36/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0641 - accuracy: 0.9802 - val_loss: 0.4036 - val_accuracy: 0.8970
# Epoch 37/55
# 11/21 [==============>...............] - ETA: 0s - loss: 0.0746 - accuracy: 0.9716
# Epoch 37: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 106ms/step - loss: 0.0800 - accuracy: 0.9710 - val_loss: 1.8554 - val_accuracy: 0.5576
# Epoch 38/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0912 - accuracy: 0.9665 - val_loss: 0.4441 - val_accuracy: 0.8848
# Epoch 39/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0749 - accuracy: 0.9726 - val_loss: 0.6468 - val_accuracy: 0.7939
# Epoch 40/55
# 12/21 [================>.............] - ETA: 0s - loss: 0.1095 - accuracy: 0.9688
# Epoch 40: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 106ms/step - loss: 0.1037 - accuracy: 0.9680 - val_loss: 0.3755 - val_accuracy: 0.9152
# Epoch 41/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1038 - accuracy: 0.9665 - val_loss: 0.8257 - val_accuracy: 0.8121
# Epoch 42/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1055 - accuracy: 0.9588 - val_loss: 0.5168 - val_accuracy: 0.8606
# Epoch 43/55
# 13/21 [=================>............] - ETA: 0s - loss: 0.1177 - accuracy: 0.9543
# Epoch 43: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 107ms/step - loss: 0.1380 - accuracy: 0.9527 - val_loss: 0.4885 - val_accuracy: 0.8182
# Epoch 44/55
# 21/21 [==============================] - 2s 101ms/step - loss: 0.1221 - accuracy: 0.9680 - val_loss: 1.8071 - val_accuracy: 0.6364
# Epoch 45/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0965 - accuracy: 0.9649 - val_loss: 0.4188 - val_accuracy: 0.8909
# Epoch 46/55
# 14/21 [===================>..........] - ETA: 0s - loss: 0.1142 - accuracy: 0.9554
# Epoch 46: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 106ms/step - loss: 0.1193 - accuracy: 0.9558 - val_loss: 0.4892 - val_accuracy: 0.8848
# Epoch 47/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0873 - accuracy: 0.9695 - val_loss: 0.4059 - val_accuracy: 0.8909
# Epoch 48/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0661 - accuracy: 0.9771 - val_loss: 0.6561 - val_accuracy: 0.8364
# Epoch 49/55
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0395 - accuracy: 0.9812
# Epoch 49: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.0574 - accuracy: 0.9771 - val_loss: 0.3064 - val_accuracy: 0.9030
# Epoch 50/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0773 - accuracy: 0.9771 - val_loss: 0.3224 - val_accuracy: 0.9152
# Epoch 51/55
# 21/21 [==============================] - 2s 99ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.3326 - val_accuracy: 0.8970
# Epoch 52/55
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0509 - accuracy: 0.9805
# Epoch 52: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 105ms/step - loss: 0.0453 - accuracy: 0.9832 - val_loss: 0.4885 - val_accuracy: 0.9091
# Epoch 53/55
# 21/21 [==============================] - 2s 101ms/step - loss: 0.0497 - accuracy: 0.9832 - val_loss: 0.5342 - val_accuracy: 0.8788
# Epoch 54/55
# 21/21 [==============================] - 2s 100ms/step - loss: 0.0571 - accuracy: 0.9802 - val_loss: 0.4127 - val_accuracy: 0.8970
# Epoch 55/55
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0470 - accuracy: 0.9816
# Epoch 55: saving model to C:/Users/Luis/Desktop/pointnet\model_trained
# 21/21 [==============================] - 2s 106ms/step - loss: 0.0454 - accuracy: 0.9817 - val_loss: 0.4820 - val_accuracy: 0.8848

# %%
#import matplotlib.pyplot as plt
#import matplotlib
#matplotlib.use('Agg')  # Usa TkAgg para gráficos interactivos

plt.figure(figsize=(12, 5))

# Gráfica de precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Precisión de Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión de Validación')
plt.title('Precisión del modelo')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

# Gráfica de pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Pérdida de Entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de Validación')
plt.title('Pérdida del modelo')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

plt.show()

# %%
import random
num_samples = 5
indices = random.sample(range(len(x_train)), num_samples)
x_test = x_train[indices]
y_test = y_train[indices]
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=1)

fig = plt.figure(figsize=(15, 15))
for i in range(num_samples):
    ax = fig.add_subplot(1, num_samples, i + 1, projection='3d')
    ax.scatter(x_test[i][:, 0], x_test[i][:, 1], x_test[i][:, 2], s=1, c='b')
    class_names = ['Bottle', 'Car', 'Laptop', 'Skateboard']
    ax.set_title(f"Real: {class_names[y_test[i]]} | Pred: {class_names[predicted_classes[i]]}")
    ax.axis("off")

plt.show()
# Out:
# 1/1 [==============================] - 0s 165ms/step
